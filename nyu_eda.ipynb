# %% [markdown]
# ### **NYU Depth Dataset V2: EDA**
#
# The NYU-Depth V2 data set is comprised of video sequences from a variety of indoor scenes as recorded by both the RGB and Depth cameras from the Microsoft Kinect. This notebook contains exploratory data analysis of the dataset before model training.

# %% [markdown]
# ##### Loading necessary libraries and dataset

# %%
import os
import glob
import random
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Set the dataset root for the train data (modify if needed)
DATASET_TRAIN_ROOT = "/projectnb/dl4ds/materials/datasets/monocular-depth-estimation/nyuv2/nyu_data/data/nyu2_train"

# Verify that the train directory exists
if not os.path.isdir(DATASET_TRAIN_ROOT):
    raise FileNotFoundError("The train directory was not found. Please check the dataset path.")

print("Training dataset directory:", DATASET_TRAIN_ROOT)
# Out:
# Training dataset directory: /projectnb/dl4ds/materials/datasets/monocular-depth-estimation/nyuv2/nyu_data/data/nyu2_train

# %% [markdown]
# This cell defines a function to traverse the training directory's subfolders, collecting all RGB images (JPG) and depth maps (PNG), and prints out the counts for each category and overall.

# %%
def get_rgb_depth_files(train_root):
    rgb_files = []
    depth_files = []
    
    # List all category subfolders (e.g., basement, bedroom, etc.)
    categories = [d for d in os.listdir(train_root) if os.path.isdir(os.path.join(train_root, d))]
    print("Found categories:", categories)
    
    # Iterate through each category and gather image file paths.
    for cat in categories:
        cat_path = os.path.join(train_root, cat)
        # List all JPG files for RGB images.
        rgb_files_cat = sorted(glob.glob(os.path.join(cat_path, "*.jpg")))
        # List all PNG files for depth maps.
        depth_files_cat = sorted(glob.glob(os.path.join(cat_path, "*.png")))
        
        # Optionally, print a summary for this category.
        print(f"Category '{cat}': {len(rgb_files_cat)} RGB images, {len(depth_files_cat)} depth maps")
        
        rgb_files.extend(rgb_files_cat)
        depth_files.extend(depth_files_cat)
    
    # Final report on the entire training set.
    print(f"\nTotal in training set: {len(rgb_files)} RGB images and {len(depth_files)} depth maps.")
    if len(rgb_files) != len(depth_files):
        print("Warning: The total number of RGB images and depth maps do not match!")
    
    return rgb_files, depth_files

# Get file lists for RGB and depth images using the updated function.
rgb_files, depth_files = get_rgb_depth_files(DATASET_TRAIN_ROOT)
# Out:
# Found categories: ['bookstore_0001e_out', 'bedroom_0113_out', 'bedroom_0057_out', 'classroom_0022_out', 'classroom_0016_out', 'furniture_store_0002d_out', 'bedroom_0065_out', 'bedroom_0014_out', 'dining_room_0037_out', 'laundry_room_0001_out', 'kitchen_0017_out', 'bedroom_0025_out', 'bedroom_0045_out', 'classroom_0011_out', 'bedroom_0078_out', 'kitchen_0048_out', 'study_0006_out', 'living_room_0004_out', 'office_0011_out', 'bathroom_0035_out', 'living_room_0078_out', 'kitchen_0019a_out', 'living_room_0018_out', 'bathroom_0042_out', 'basement_0001b_out', 'bedroom_0035_out', 'office_0026_out', 'living_room_0005_out', 'bathroom_0006_out', 'bedroom_0086_out', 'living_room_0047b_out', 'bedroom_0051_out', 'bedroom_0125a_out', 'bedroom_0069_out', 'bedroom_0132_out', 'bedroom_0016_out', 'study_0008_out', 'bedroom_0053_out', 'kitchen_0029a_out', 'bathroom_0050_out', 'dining_room_0031_out', 'kitchen_0029b_out', 'office_0025_out', 'bedroom_0041_out', 'furniture_store_0001c_out', 'bathroom_0010_out', 'printer_room_0001_out', 'study_room_0005b_out', 'bedroom_0052_out', 'office_0024_out', 'living_room_0039_out', 'bedroom_0019_out', 'bedroom_0033_out', 'bathroom_0041_out', 'living_room_0038_out', 'bedroom_0081_out', 'bookstore_0001i_out', 'kitchen_0037_out', 'dinette_0001_out', 'computer_lab_0002_out', 'study_0005_out', 'living_room_0050_out', 'bedroom_0107_out', 'bathroom_0054_out', 'living_room_0086b_out', 'bedroom_0004_out', 'home_office_0013_out', 'bathroom_0023_out', 'nyu_office_1_out', 'furniture_store_0001e_out', 'bedroom_0106_out', 'bedroom_0116_out', 'bedroom_0097_out', 'furniture_store_0002b_out', 'dining_room_0007_out', 'home_office_0004_out', 'furniture_store_0001a_out', 'bedroom_0060_out', 'bathroom_0030_out', 'living_room_0071_out', 'bedroom_0096_out', 'study_room_0005a_out', 'kitchen_0010_out', 'reception_room_0002_out', 'kitchen_0035a_out', 'bedroom_0140_out', 'bedroom_0017_out', 'bedroom_0059_out', 'bathroom_0045a_out', 'home_office_0008_out', 'bathroom_0007_out', 'living_room_0047a_out', 'bedroom_0072_out', 'living_room_0068_out', 'kitchen_0045a_out', 'living_room_0046a_out', 'reception_room_0001a_out', 'living_room_0063_out', 'dining_room_0024_out', 'kitchen_0029c_out', 'kitchen_0043_out', 'living_room_0012_out', 'bathroom_0033_out', 'bedroom_0056a_out', 'bedroom_0082_out', 'bedroom_0074_out', 'bedroom_0094_out', 'living_room_0082_out', 'bedroom_0039_out', 'bedroom_0129_out', 'living_room_0020_out', 'reception_room_0004_out', 'reception_room_0001b_out', 'dining_room_0004_out', 'cafe_0001a_out', 'conference_room_0002_out', 'furniture_store_0002c_out', 'nyu_office_0_out', 'kitchen_0011a_out', 'living_room_0085_out', 'office_0018_out', 'dining_room_0029_out', 'bookstore_0001j_out', 'living_room_0022_out', 'bookstore_0001h_out', 'living_room_0086a_out', 'classroom_0012_out', 'living_room_0006_out', 'kitchen_0003_out', 'living_room_0037_out', 'student_lounge_0001_out', 'bedroom_0031_out', 'kitchen_0011b_out', 'dining_room_0028_out', 'bedroom_0063_out', 'living_room_0042b_out', 'kitchen_0041_out', 'kitchen_0060_out', 'kitchen_0049_out', 'living_room_0032_out', 'conference_room_0001_out', 'playroom_0002_out', 'basement_0001a_out', 'bedroom_0136_out', 'playroom_0004_out', 'bathroom_0005_out', 'living_room_0070_out', 'bedroom_0076a_out', 'home_office_0007_out', 'furniture_store_0001d_out', 'bathroom_0002_out', 'kitchen_0006_out', 'bathroom_0016_out', 'bathroom_0011_out', 'classroom_0005_out', 'office_0006_out', 'dining_room_0034_out', 'living_room_0055_out', 'bedroom_0028_out', 'bedroom_0066_out', 'bedroom_0029_out', 'living_room_0011_out', 'dining_room_0033_out', 'living_room_0010_out', 'kitchen_0028a_out', 'foyer_0002_out', 'office_0004_out', 'bedroom_0012_out', 'furniture_store_0001b_out', 'bedroom_0080_out', 'playroom_0003_out', 'bedroom_0038_out', 'office_kitchen_0001a_out', 'living_room_0058_out', 'dining_room_0001b_out', 'office_0021_out', 'bedroom_0062_out', 'bedroom_0047_out', 'bedroom_0034_out', 'bathroom_0014a_out', 'kit ...
# Category 'bookstore_0001e_out': 331 RGB images, 331 depth maps
# Category 'bedroom_0113_out': 166 RGB images, 166 depth maps
# Category 'bedroom_0057_out': 63 RGB images, 63 depth maps
# Category 'classroom_0022_out': 169 RGB images, 169 depth maps
# Category 'classroom_0016_out': 114 RGB images, 114 depth maps
# Category 'furniture_store_0002d_out': 96 RGB images, 96 depth maps
# Category 'bedroom_0065_out': 65 RGB images, 65 depth maps
# Category 'bedroom_0014_out': 103 RGB images, 103 depth maps
# Category 'dining_room_0037_out': 250 RGB images, 250 depth maps
# Category 'laundry_room_0001_out': 95 RGB images, 95 depth maps
# Category 'kitchen_0017_out': 163 RGB images, 163 depth maps
# Category 'bedroom_0025_out': 223 RGB images, 223 depth maps
# Category 'bedroom_0045_out': 33 RGB images, 33 depth maps
# Category 'classroom_0011_out': 105 RGB images, 105 depth maps
# Category 'bedroom_0078_out': 240 RGB images, 240 depth maps
# Category 'kitchen_0048_out': 382 RGB images, 382 depth maps
# Category 'study_0006_out': 58 RGB images, 58 depth maps
# Category 'living_room_0004_out': 255 RGB images, 255 depth maps
# Category 'office_0011_out': 243 RGB images, 243 depth maps
# Category 'bathroom_0035_out': 56 RGB images, 56 depth maps
# Category 'living_room_0078_out': 211 RGB images, 211 depth maps
# Category 'kitchen_0019a_out': 428 RGB images, 428 depth maps
# Category 'living_room_0018_out': 308 RGB images, 308 depth maps
# Category 'bathroom_0042_out': 71 RGB images, 71 depth maps
# Category 'basement_0001b_out': 69 RGB images, 69 depth maps
# Category 'bedroom_0035_out': 53 RGB images, 53 depth maps
# Category 'office_0026_out': 274 RGB images, 274 depth maps
# Category 'living_room_0005_out': 229 RGB images, 229 depth maps
# Category 'bathroom_0006_out': 90 RGB images, 90 depth maps
# Category 'bedroom_0086_out': 186 RGB images, 186 depth maps
# Category 'living_room_0047b_out': 285 RGB images, 285 depth maps
# Category 'bedroom_0051_out': 315 RGB images, 315 depth maps
# Category 'bedroom_0125a_out': 47 RGB images, 47 depth maps
# Category 'bedroom_0069_out': 178 RGB images, 178 depth maps
# Category 'bedroom_0132_out': 69 RGB images, 69 depth maps
# Category 'bedroom_0016_out': 313 RGB images, 313 depth maps
# Category 'study_0008_out': 83 RGB images, 83 depth maps
# Category 'bedroom_0053_out': 156 RGB images, 156 depth maps
# Category 'kitchen_0029a_out': 53 RGB images, 53 depth maps
# Category 'bathroom_0050_out': 21 RGB images, 21 depth maps
# Category 'dining_room_0031_out': 576 RGB images, 576 depth maps
# Category 'kitchen_0029b_out': 88 RGB images, 88 depth maps
# Category 'office_0025_out': 65 RGB images, 65 depth maps
# Category 'bedroom_0041_out': 109 RGB images, 109 depth maps
# Category 'furniture_store_0001c_out': 48 RGB images, 48 depth maps
# Category 'bathroom_0010_out': 84 RGB images, 84 depth maps
# Category 'printer_room_0001_out': 117 RGB images, 117 depth maps
# Category 'study_room_0005b_out': 133 RGB images, 133 depth maps
# Category 'bedroom_0052_out': 309 RGB images, 309 depth maps
# Category 'office_0024_out': 182 RGB images, 182 depth maps
# Category 'living_room_0039_out': 272 RGB images, 272 depth maps
# Category 'bedroom_0019_out': 243 RGB images, 243 depth maps
# Category 'bedroom_0033_out': 241 RGB images, 241 depth maps
# Category 'bathroom_0041_out': 124 RGB images, 124 depth maps
# Category 'living_room_0038_out': 171 RGB images, 171 depth maps
# Category 'bedroom_0081_out': 71 RGB images, 71 depth maps
# Category 'bookstore_0001i_out': 241 RGB images, 241 depth maps
# Category 'kitchen_0037_out': 169 RGB images, 169 depth maps
# Category 'dinette_0001_out': 150 RGB images, 150 depth maps
# Category 'computer_lab_0002_out': 73 RGB images, 73 depth maps
# Category 'study_0005_out': 27 RGB images, 27 depth maps
# Category 'living_room_0050_out': 407 RGB images, 407 depth maps
# Category 'bedroom_0107_out': 75 RGB images, 75 depth maps
# Category 'bathroom_0054_out': 39 RGB images, 39 depth maps
# Category 'living_room_0086b_out': 68 RGB images, 68 depth maps
# Category 'bedroom_0004_out': 275 RGB images, 275 depth maps
# Category 'home_office_0013_out': 127 RGB images, 127 depth maps
# Category 'bathroom_0023_out': 30 RGB images, 30 depth maps
# Category 'nyu_office_1_out': 150 RGB images, 150 depth maps
# Category 'furniture_store_0001e_out': 136 RGB images, 136 depth maps
# Category 'bedroom_0106_out': 211 RGB images, 211 depth maps
# Category 'bedroom_0116_out': 20 RGB images, 20 depth maps
# Category 'bedroom_0097_out': 94 RGB images, 94 depth maps
# Category 'furniture_store_0002b_out': 391 RGB images, 391 depth maps
# Category 'dining_room_0007_out': 334 RGB images, 334 depth maps
# Category 'home_office_0004_out': 269 RGB images, 269 depth maps
# Category 'furniture_store_0001a_out': 79 RGB images, 79 depth maps
# Category 'bedroom_0060_out': 148 RGB images, 148 depth maps
# Category 'bathroom_0030_out': 79 RGB images, 79 depth maps
# Category 'living_room_0071_out': 71 RGB images, 71 depth maps
# Category 'bedroom_0096_out': 135 RGB images, 135 depth maps
# Category 'study_room_0005a_out': 86 RGB images, 86 depth maps
# Category 'kitchen_0010_out': 188 RGB images, 188 depth maps
# Category 'reception_room_0002_out': 246 RGB images, 246 depth maps
# Category 'kitchen_0035a_out': 83 RGB images, 83 depth maps
# Category 'bedroom_0140_out': 254 RGB images, 254 depth maps
# Category 'bedroom_0017_out': 220 RGB images, 220 depth maps
# Category 'bedroom_0059_out': 136 RGB images, 136 depth maps
# Category 'bathroom_0045a_out': 91 RGB images, 91 depth maps
# Category 'home_office_0008_out': 248 RGB images, 248 depth maps
# Category 'bathroom_0007_out': 174 RGB images, 174 depth maps
# Category 'living_room_0047a_out': 98 RGB images, 98 depth maps
# Category 'bedroom_0072_out': 260 RGB images, 260 depth maps
# Category 'living_room_0068_out': 170 RGB images, 170 depth maps
# Category 'kitchen_0045a_out': 291 RGB images, 291 depth maps
# Category 'living_room_0046a_out': 147 RGB images, 147 depth maps
# Category 'reception_room_0001a_out': 172 RGB images, 172 depth maps
# Category 'living_room_0063_out': 246 RGB images, 246 depth maps
# Category 'dining_room_0024_out': 261 RGB images, 261 depth maps
# Category 'kitchen_0029c_out': 256 RGB images, 256 depth maps
# Category 'kitchen_0043_out': 374 RGB images, 374 depth maps
# Category 'living_room_0012_out': 319 RGB images, 319 depth maps
# Category 'bathroom_0033_out': 91 RGB images, 91 depth maps
# Category 'bedroom_0056a_out': 160 RGB images, 160 depth maps
# Category 'bedroom_0082_out': 89 RGB images, 89 depth maps
# Category 'bedroom_0074_out': 188 RGB images, 188 depth maps
# Category 'bedroom_0094_out': 64 RGB images, 64 depth maps
# Category 'living_room_0082_out': 97 RGB images, 97 depth maps
# Category 'bedroom_0039_out': 54 RGB images, 54 depth maps
# Category 'bedroom_0129_out': 137 RGB images, 137 depth maps
# Category 'living_room_0020_out': 345 RGB images, 345 depth maps
# Category 'reception_room_0004_out': 131 RGB images, 131 depth maps
# Category 'reception_room_0001b_out': 179 RGB images, 179 depth maps
# Category 'dining_room_0004_out': 175 RGB images, 175 depth maps
# Category 'cafe_0001a_out': 126 RGB images, 126 depth maps
# Category 'conference_room_0002_out': 73 RGB images, 73 depth maps
# Category 'furniture_store_0002c_out': 112 RGB images, 112 depth maps
# Category 'nyu_office_0_out': 615 RGB images, 615 depth maps
# Category 'kitchen_0011a_out': 203 RGB images, 203 depth maps
# Category 'living_room_0085_out': 91 RGB images, 91 depth maps
# Category 'office_0018_out': 76 RGB images, 76 depth maps
# Category 'dining_room_0029_out': 207 RGB images, 207 depth maps
# Category 'bookstore_0001j_out': 446 RGB images, 446 depth maps
# Category 'living_room_0022_out': 621 RGB images, 621 depth maps
# Category 'bookstore_0001h_out': 248 RGB images, 248 depth maps
# Category 'living_room_0086a_out': 118 RGB images, 118 depth maps
# Category 'classroom_0012_out': 74 RGB images, 74 depth maps
# Category 'living_room_0006_out': 39 RGB images, 39 depth maps
# Category 'kitchen_0003_out': 253 RGB images, 253 depth maps
# Category 'living_room_0037_out': 94 RGB images, 94 depth maps
# Category 'student_lounge_0001_out': 379 RGB images, 379 depth maps
# Category 'bedroom_0031_out': 74 RGB images, 74 depth maps
# Category 'kitchen_0011b_out': 123 RGB images, 123 depth maps
# Category 'dining_room_0028_out': 217 RGB images, 217 depth maps
# Category 'bedroom_0063_out': 209 RGB images, 209 depth maps
# Category 'living_room_0042b_out': 138 RGB images, 138 depth maps
# Category 'kitchen_0041_out': 73 RGB images, 73 depth maps
# Category 'kitchen_0060_out': 257 RGB images, 257 depth maps
# Category 'kitchen_0049_out': 332 RGB images, 332 depth maps
# Category 'living_room_0032_out': 64 RGB images, 64 depth maps
# Category 'conference_room_0001_out': 213 RGB images, 213 depth maps
# Category 'playroom_0002_out': 227 RGB images, 227 depth maps
# Category 'basement_0001a_out': 281 RGB images, 281 depth maps
# Category 'bedroom_0136_out': 230 RGB images, 230 depth maps
# Category 'playroom_0004_out': 185 RGB images, 185 depth maps
# Category 'bathroom_0005_out': 77 RGB images, 77 depth maps
# Category 'living_room_0070_out': 158 RGB images, 158 depth maps
# Category 'bedroom_0076a_out': 206 RGB images, 206 depth maps
# Category 'home_office_0007_out': 92 RGB images, 92 depth maps
# Category 'furniture_store_0001d_out': 408 RGB images, 408 depth maps
# Category 'bathroom_0002_out': 71 RGB images, 71 depth maps
# Category 'kitchen_0006_out': 114 RGB images, 114 depth maps
# Category 'bathroom_0016_out': 54 RGB images, 54 depth maps
# Category 'bathroom_0011_out': 70 RGB images, 70 depth maps
# Category 'classroom_0005_out': 68 RGB images, 68 depth maps
# Category 'office_0006_out': 239 RGB images, 239 depth maps
# Category 'dining_room_0034_out': 326 RGB images, 326 depth maps
# Category 'living_room_0055_out': 205 RGB images, 205 depth maps
# Category 'bedroom_0028_out': 111 RGB images, 111 depth maps
# Category 'bedroom_0066_out': 89 RGB images, 89 depth maps
# Category 'bedroom_0029_out': 109 RGB images, 109 depth maps
# Category 'living_room_0011_out': 197 RGB images, 197 depth maps
# Category 'dining_room_0033_out': 278 RGB images, 278 depth maps
# Category 'living_room_0010_out': 347 RGB images, 347 depth maps
# Category 'kitchen_0028a_out': 287 RGB images, 287 depth maps
# Category 'foyer_0002_out': 74 RGB images, 74 depth maps
# Category 'office_0004_out': 154 RGB images, 154 depth maps
# Category 'bedroom_0012_out': 113 RGB images, 113 depth maps
# Category 'furniture_store_0001b_out': 146 RGB images, 146 depth maps
# Category 'bedroom_0080_out': 101 RGB images, 101 depth maps
# Category 'playroom_0003_out': 304 RGB images, 304 depth maps
# Category 'bedroom_0038_out': 36 RGB images, 36 depth maps
# Category 'office_kitchen_0001a_out': 127 RGB images, 127 depth maps
# Category 'living_room_0058_out': 401 RGB images, 401 depth maps
# Category 'dining_room_0001b_out': 342 RGB images, 342 depth maps
# Category 'office_0021_out': 103 RGB images, 103 depth maps
# Category 'bedroom_0062_out': 227 RGB images, 227 depth maps
# Category 'bedroom_0047_out': 95 RGB images, 95 depth maps
# Category 'bedroom_0034_out': 182 RGB images, 182 depth maps
# Category 'bathroom_0014a_out': 116 RGB images, 116 depth maps
# Category 'kitchen_0008_out': 75 RGB images, 75 depth maps
# Category 'living_room_0062_out': 314 RGB images, 314 depth maps
# Category 'bedroom_0125b_out': 140 RGB images, 140 depth maps
# Category 'office_0012_out': 153 RGB images, 153 depth maps
# Category 'bedroom_0079_out': 87 RGB images, 87 depth maps
# Category 'kitchen_0047_out': 218 RGB images, 218 depth maps
# Category 'living_room_0083_out': 152 RGB images, 152 depth maps
# Category 'bedroom_0098_out': 112 RGB images, 112 depth maps
# Category 'study_0004_out': 124 RGB images, 124 depth maps
# Category 'bedroom_0036_out': 11 RGB images, 11 depth maps
# Category 'dining_room_0014_out': 175 RGB images, 175 depth maps
# Category 'bedroom_0056b_out': 70 RGB images, 70 depth maps
# Category 'playroom_0006_out': 213 RGB images, 213 depth maps
# Category 'classroom_0004_out': 152 RGB images, 152 depth maps
# Category 'indoor_balcony_0001_out': 66 RGB images, 66 depth maps
# Category 'bedroom_0050_out': 274 RGB images, 274 depth maps
# Category 'study_0003_out': 171 RGB images, 171 depth maps
# Category 'kitchen_0050_out': 308 RGB images, 308 depth maps
# Category 'kitchen_0053_out': 359 RGB images, 359 depth maps
# Category 'bedroom_0026_out': 218 RGB images, 218 depth maps
# Category 'kitchen_0052_out': 257 RGB images, 257 depth maps
# Category 'bathroom_0053_out': 82 RGB images, 82 depth maps
# Category 'bedroom_0090_out': 55 RGB images, 55 depth maps
# Category 'bedroom_0067b_out': 49 RGB images, 49 depth maps
# Category 'bathroom_0013_out': 106 RGB images, 106 depth maps
# Category 'classroom_0010_out': 109 RGB images, 109 depth maps
# Category 'bedroom_0124_out': 55 RGB images, 55 depth maps
# Category 'living_room_0029_out': 173 RGB images, 173 depth maps
# Category 'bathroom_0039_out': 114 RGB images, 114 depth maps
# Category 'bookstore_0001d_out': 509 RGB images, 509 depth maps
# Category 'dining_room_0015_out': 404 RGB images, 404 depth maps
# Category 'home_storage_0001_out': 224 RGB images, 224 depth maps
# Category 'classroom_0006_out': 293 RGB images, 293 depth maps
# Category 'bathroom_0051_out': 83 RGB images, 83 depth maps
# Category 'office_kitchen_0001b_out': 97 RGB images, 97 depth maps
# Category 'bedroom_0104_out': 172 RGB images, 172 depth maps
# Category 'living_room_0042a_out': 55 RGB images, 55 depth maps
# Category 'kitchen_0028b_out': 114 RGB images, 114 depth maps
# Category 'bedroom_0118_out': 44 RGB images, 44 depth maps
# Category 'bedroom_0067a_out': 66 RGB images, 66 depth maps
# Category 'home_office_0005_out': 202 RGB images, 202 depth maps
# Category 'dining_room_0008_out': 284 RGB images, 284 depth maps
# Category 'bedroom_0100_out': 105 RGB images, 105 depth maps
# Category 'bedroom_0015_out': 150 RGB images, 150 depth maps
# Category 'bedroom_0130_out': 139 RGB images, 139 depth maps
# Category 'bathroom_0019_out': 136 RGB images, 136 depth maps
# Category 'living_room_0046b_out': 178 RGB images, 178 depth maps
# Category 'cafe_0001c_out': 157 RGB images, 157 depth maps
# Category 'bedroom_0021_out': 167 RGB images, 167 depth maps
# Category 'excercise_room_0001_out': 181 RGB images, 181 depth maps
# Category 'bedroom_0020_out': 169 RGB images, 169 depth maps
# Category 'kitchen_0059_out': 134 RGB images, 134 depth maps
# Category 'classroom_0018_out': 77 RGB images, 77 depth maps
# Category 'bathroom_0048_out': 148 RGB images, 148 depth maps
# Category 'furniture_store_0001f_out': 34 RGB images, 34 depth maps
# Category 'dining_room_0019_out': 243 RGB images, 243 depth maps
# Category 'bathroom_0056_out': 77 RGB images, 77 depth maps
# Category 'bedroom_0126_out': 100 RGB images, 100 depth maps
# Category 'bathroom_0001_out': 33 RGB images, 33 depth maps
# Category 'dining_room_0012_out': 329 RGB images, 329 depth maps
# Category 'kitchen_0045b_out': 226 RGB images, 226 depth maps
# Category 'home_office_0011_out': 143 RGB images, 143 depth maps
# Category 'furniture_store_0002a_out': 592 RGB images, 592 depth maps
# Category 'home_office_0006_out': 265 RGB images, 265 depth maps
# Category 'bedroom_0042_out': 86 RGB images, 86 depth maps
# Category 'dining_room_0023_out': 261 RGB images, 261 depth maps
# Category 'bedroom_0071_out': 268 RGB images, 268 depth maps
# Category 'kitchen_0016_out': 172 RGB images, 172 depth maps
# Category 'bookstore_0001f_out': 732 RGB images, 732 depth maps
# Category 'dining_room_0010_out': 159 RGB images, 159 depth maps
# Category 'bathroom_0024_out': 85 RGB images, 85 depth maps
# Category 'bathroom_0034_out': 126 RGB images, 126 depth maps
# Category 'study_room_0004_out': 307 RGB images, 307 depth maps
# Category 'bedroom_0040_out': 129 RGB images, 129 depth maps
# Category 'living_room_0040_out': 473 RGB images, 473 depth maps
# Category 'kitchen_0051_out': 506 RGB images, 506 depth maps
# Category 'office_0023_out': 69 RGB images, 69 depth maps
# Category 'living_room_0069a_out': 175 RGB images, 175 depth maps
# Category 'kitchen_0035b_out': 461 RGB images, 461 depth maps
# Category 'living_room_0019_out': 343 RGB images, 343 depth maps
# Category 'dining_room_0002_out': 26 RGB images, 26 depth maps
# Category 'bathroom_0028_out': 249 RGB images, 249 depth maps
# Category 'bookstore_0001g_out': 396 RGB images, 396 depth maps
# Category 'kitchen_0033_out': 278 RGB images, 278 depth maps
# Category 'office_0003_out': 100 RGB images, 100 depth maps
# Category 'dining_room_0016_out': 306 RGB images, 306 depth maps
# Category 'office_0009_out': 127 RGB images, 127 depth maps
# Category 'bathroom_0049_out': 90 RGB images, 90 depth maps
# Category 'classroom_0003_out': 151 RGB images, 151 depth maps
# Category 'kitchen_0031_out': 301 RGB images, 301 depth maps
# Category 'office_0019_out': 87 RGB images, 87 depth maps
# Category 'bedroom_0138_out': 151 RGB images, 151 depth maps
# Category 'bedroom_0120_out': 131 RGB images, 131 depth maps
# Category 'cafe_0001b_out': 104 RGB images, 104 depth maps
# Category 'bathroom_0055_out': 88 RGB images, 88 depth maps
# Category 'office_kitchen_0003_out': 186 RGB images, 186 depth maps
# Category 'bedroom_0010_out': 180 RGB images, 180 depth maps
# Category 'dining_room_0013_out': 286 RGB images, 286 depth maps
# Category 'kitchen_0019b_out': 64 RGB images, 64 depth maps
# Category 'living_room_0035_out': 160 RGB images, 160 depth maps
# Category 'living_room_0033_out': 103 RGB images, 103 depth maps
# Category 'bathroom_0057_out': 50 RGB images, 50 depth maps
# Category 'living_room_0069b_out': 122 RGB images, 122 depth maps
# Category 'living_room_0067_out': 143 RGB images, 143 depth maps
#
# Total in training set: 50688 RGB images and 50688 depth maps.

# %% [markdown]
# #### Visualizing Sample RGB-Depth Pairs
#
# This cell defines a function to randomly select and display RGB images alongside their corresponding depth maps. It converts images for proper visualization and plots them side by side for easy inspection.

# %%
def visualize_samples(rgb_files, depth_files, num_samples=3):
    # Ensure that we have pairs to sample from.
    sample_count = min(len(rgb_files), len(depth_files))
    sample_indices = random.sample(range(sample_count), num_samples)
    
    for idx in sample_indices:
        # Load the RGB image and convert color space for display.
        rgb_img = cv2.imread(rgb_files[idx], cv2.IMREAD_COLOR)
        rgb_img = cv2.cvtColor(rgb_img, cv2.COLOR_BGR2RGB)
        
        # Load the corresponding depth image as grayscale.
        depth_img = cv2.imread(depth_files[idx], cv2.IMREAD_GRAYSCALE)
        
        # Display the images side by side.
        plt.figure(figsize=(10, 4))
        
        plt.subplot(1, 2, 1)
        plt.imshow(rgb_img)
        plt.title("RGB Image")
        plt.axis("off")
        
        plt.subplot(1, 2, 2)
        plt.imshow(depth_img)
        plt.title("Depth Map")
        plt.axis("off")
        
        plt.show()

# Visualize 3 random RGB-depth pairs from the training set.
visualize_samples(rgb_files, depth_files, num_samples=3)

# %% [markdown]
# #### Analyzing Depth Distribution
#
# This cell computes key statistics (min, max, mean, median, standard deviation) from a sample of depth maps. It aggregates pixel values from 50 depth images and plots a histogram to visualize the overall distribution.

# %%
def analyze_depth_distribution(depth_files, sample_count=50):
    all_depth_values = []
    sample_for_analysis = min(sample_count, len(depth_files))
    
    for i in range(sample_for_analysis):
        depth_img = cv2.imread(depth_files[i], cv2.IMREAD_UNCHANGED)
        if depth_img is not None:
            # Flatten the depth image to 1D array.
            depth_values = depth_img.flatten()
            # Optionally, filter out zero values if they represent missing data:
            # depth_values = depth_values[depth_values > 0]
            all_depth_values.extend(depth_values.tolist())
    
    all_depth_values = np.array(all_depth_values)
    
    # Print and display summary statistics.
    print("Depth Statistics from Sample:")
    print(f"Min: {np.min(all_depth_values)}")
    print(f"Max: {np.max(all_depth_values)}")
    print(f"Mean: {np.mean(all_depth_values):.2f}")
    print(f"Median: {np.median(all_depth_values):.2f}")
    print(f"Standard Deviation: {np.std(all_depth_values):.2f}")
    
    # Plot histogram of depth values.
    plt.figure(figsize=(8, 4))
    plt.hist(all_depth_values, bins=50, color='gray', edgecolor='black')
    plt.title("Distribution of Depth Values")
    plt.xlabel("Depth Value")
    plt.ylabel("Frequency")
    plt.show()

# Analyze depth distribution using 50 samples.
analyze_depth_distribution(depth_files, sample_count=50)
# Out:
# Depth Statistics from Sample:
# Min: 25
# Max: 254
# Mean: 73.54
# Median: 47.00
# Standard Deviation: 52.83

# %% [markdown]
# #### Detecting Depth Outliers
#
# This cell computes the mean depth for each image and identifies outliers that deviate by more than 3 standard deviations from the overall mean. It prints the number of detected outliers, helping flag potentially problematic depth maps.

# %%
def detect_depth_outliers(depth_files, threshold=3):
    depth_means = []
    
    for f in depth_files:
        depth_img = cv2.imread(f, cv2.IMREAD_UNCHANGED)
        if depth_img is not None:
            depth_means.append(np.mean(depth_img))
    depth_means = np.array(depth_means)
    
    overall_mean = np.mean(depth_means)
    overall_std = np.std(depth_means)
    
    outlier_indices = np.where(np.abs(depth_means - overall_mean) > threshold * overall_std)[0]
    print(f"Found {len(outlier_indices)} outliers out of {len(depth_files)} images.")
    return outlier_indices, depth_means

outliers, means = detect_depth_outliers(depth_files)
# Out:
# Found 92 outliers out of 50688 images.
